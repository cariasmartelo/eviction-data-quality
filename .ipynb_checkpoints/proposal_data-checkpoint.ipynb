# %% [markdown]
# # Overview of data available on Eviction Lab

# %%
# %load_ext autoreload
# %autoreload 2
import download_eviction_data as ded
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Download data

# %%
#ded.download_from_api('IL', download_dict=True) #Data already downloaded
il_tract_df = ded.import_csv('inputs/eviction/IL/tracts.csv')
il_tract_gdf = ded.import_geojson('inputs/eviction/IL/tracts.geojson')

# %%
il_tract_df.shape
# Out:
# (53091, 27)

# %%
il_tract_df.groupby('year').size()
# Out:
# year
# 2000    3123
# 2001    3123
# 2002    3123
# 2003    3123
# 2004    3123
# 2005    3123
# 2006    3123
# 2007    3123
# 2008    3123
# 2009    3123
# 2010    3123
# 2011    3123
# 2012    3123
# 2013    3123
# 2014    3123
# 2015    3123
# 2016    3123
# dtype: int64

# %% [markdown]
# We have eviction data of 3,123 tracts in Illinois from 2000 to 2016

# %%
il_tract_df.columns
# Out:
# Index(['GEOID', 'year', 'name', 'parent-location', 'population',
#        'poverty-rate', 'renter-occupied-households', 'pct-renter-occupied',
#        'median-gross-rent', 'median-household-income', 'median-property-value',
#        'rent-burden', 'pct-white', 'pct-af-am', 'pct-hispanic', 'pct-am-ind',
#        'pct-asian', 'pct-nh-pi', 'pct-multiple', 'pct-other',
#        'eviction-filings', 'evictions', 'eviction-rate',
#        'eviction-filing-rate', 'low-flag', 'imputed', 'subbed'],
#       dtype='object')

# %% [markdown]
# ## Variables:
# * Demographic:
#     - Population
#     - poverty rate
#     - median household income
#     - % white, % african american, % hispanic, % american indian, % asian, % native hawaian, % other
# * Real estate characteristics:
#     - Freq and % of renter occupied households.
#     - Median gross rent
#     - Media property value
#     - Rent burden (Median gross rent as % of household income)
# * Evictions:
#     - Freq and rate of evictions
#     - Freq and rate of eviction filing
# * Other:
#     - low-flag: Evictions believed to be under estimated.
#     - subbed: Data pulled from source different than Eviction Lab
#     - inputed: Data inputed.

# %%
ded.describe(il_tract_df, 'demographics')
# Out:
#          population  poverty-rate  median-household-income     pct-white  \
# count  53086.000000  53086.000000             52997.000000  53086.000000
# mean    4070.276280     11.978787             55575.780733     63.488012
# std     1768.746921     12.161184             26598.391453     32.830338
# min        0.000000      0.000000                 0.000000      0.000000
# 25%     2837.000000      3.670000             38021.520000     39.640000
# 50%     3859.680000      7.830000             50781.000000     76.150000
# 75%     5053.000000     15.830000             67750.000000     91.080000
# max    27626.000000    100.000000            246613.620000    100.000000
#
#           pct-af-am  pct-hispanic    pct-am-ind     pct-asian     pct-nh-pi  \
# count  53086.000000  53086.000000  53086.000000  53086.000000  53086.000000
# mean      16.901330     13.878407      0.131450      3.861670      0.022273
# std       29.084098     20.738490      0.281739      6.597923      0.119569
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.670000      1.750000      0.000000      0.190000      0.000000
# 50%        3.140000      5.100000      0.000000      1.190000      0.000000
# 75%       14.590000     15.040000      0.160000      4.600000      0.000000
# max      100.000000    100.000000      6.180000     88.750000      3.080000
#
#        pct-multiple     pct-other
# count  53086.000000  53086.000000
# mean       1.372254      0.144698
# std        1.382194      0.439019
# min        0.000000      0.000000
# 25%        0.500000      0.000000
# 50%        1.020000      0.000000
# 75%        1.840000      0.120000
# max       20.580000     10.490000

# %%
ded.describe(il_tract_df, 'real-estate')
# Out:
#        renter-occupied-households  pct-renter-occupied  median-gross-rent  \
# count                53091.000000         53086.000000       52575.000000
# mean                   505.672487            33.845751         834.122154
# std                    413.353958            22.552387         352.416056
# min                      0.000000             0.000000           0.000000
# 25%                    224.000000            16.200000         596.000000
# 50%                    402.000000            28.190000         779.000000
# 75%                    655.000000            49.460000         978.000000
# max                   6213.000000           100.000000        3501.000000
#
#        median-property-value   rent-burden
# count           5.284800e+04  52726.000000
# mean            1.912704e+05     28.927126
# std             1.369509e+05      8.550564
# min             0.000000e+00      0.000000
# 25%             9.550000e+04     23.300000
# 50%             1.563000e+05     27.400000
# 75%             2.424545e+05     33.100000
# max             1.310700e+06     50.100000

# %%
ded.describe(il_tract_df, 'evictions')
# Out:
#        eviction-filings     evictions  eviction-rate  eviction-filing-rate
# count      51167.000000  51167.000000   51167.000000          51167.000000
# mean          20.799187      8.491352       1.827028              4.213532
# std           26.469564     11.923898       2.319430              4.729722
# min            0.000000      0.000000       0.000000              0.000000
# 25%            5.000000      1.000000       0.240000              1.560000
# 50%           12.000000      4.000000       1.240000              3.040000
# 75%           27.000000     11.000000       2.600000              5.560000
# max          396.000000    151.000000     100.000000            300.000000

# %%
ded.map(il_tract_gdf, 'eviction-rate', 2016)

# %%
ded.map(il_tract_gdf, 'population', 2016)

# %%
ded.map(il_tract_gdf, 'poverty-rate', 2016)

# %%
ded.see_scatterplot(il_tract_df, 'rent-burden', 'eviction-rate')

# %%
ded.see_scatterplot(il_tract_df, 'pct-renter-occupied', 'eviction-rate', colorcol = 'poverty-rate')

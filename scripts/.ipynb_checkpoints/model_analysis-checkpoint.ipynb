# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
models = pd.read_csv("third_models.csv")
models.head()
# Out:
#    Unnamed: 0 model_type                                                clf  \
# 0           0         DT  DecisionTreeClassifier(class_weight=None, crit...
# 1           1         DT  DecisionTreeClassifier(class_weight=None, crit...
# 2           2         DT  DecisionTreeClassifier(class_weight=None, crit...
# 3           3         DT  DecisionTreeClassifier(class_weight=None, crit...
# 4           4         DT  DecisionTreeClassifier(class_weight=None, crit...
#
#                                           parameters  split_date  \
# 0  {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 1  {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 2  {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 3  {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 4  {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
#
#   min_year_in_train max_year_in_train min_year_in_test max_year_in_test  \
# 0        2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 1        2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 2        2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 3        2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 4        2010-01-01        2012-01-01       2013-01-01       2013-01-01
#
#    baseline  ...   p_at_20  recall_at_20  f1_at_20   p_at_30  recall_at_30  \
# 0  0.100756  ...  0.278481        0.5500  0.369748  0.184874        0.5500
# 1  0.100756  ...  0.278481        0.5500  0.369748  0.184874        0.5500
# 2  0.100756  ...  0.278481        0.5500  0.369748  0.184874        0.5500
# 3  0.100756  ...  0.164557        0.3250  0.218487  0.281513        0.8375
# 4  0.100756  ...  0.082278        0.1625  0.109244  0.142857        0.4250
#
#    f1_at_30   p_at_50  recall_at_50  f1_at_50   auc-roc
# 0  0.276730  0.201511           1.0   0.33543  0.749790
# 1  0.276730  0.201511           1.0   0.33543  0.749790
# 2  0.276730  0.201511           1.0   0.33543  0.749790
# 3  0.421384  0.201511           1.0   0.33543  0.782195
# 4  0.213836  0.201511           1.0   0.33543  0.566544
#
# [5 rows x 32 columns]

# %%
summary = pd.pivot_table(models,
                         index=['model_type', 'split_date'],
                         aggfunc='mean',
                         fill_value=0)
f1_list = ['f1_at_1', 'f1_at_2', 'f1_at_5',
           'f1_at_10', 'f1_at_20', 'f1_at_30', 'f1_at_50']
p_list = ['p_at_1', 'p_at_2', 'p_at_5', 
          'p_at_10', 'p_at_20', 'p_at_30', 'p_at_50']
recall_list = ['recall_at_1', 'recall_at_2', 'recall_at_5', 
               'recall_at_10', 'recall_at_20', 'recall_at_30', 'recall_at_50']

# %% [markdown]
# # Ranking models based on f1 score at k=10%

# %%
summary[f1_list].sort_values(by='f1_at_10',ascending=False)
# Out:
#                          p_at_1    p_at_2    p_at_5   p_at_10   p_at_20  \
# model_type split_date
# RF         2013-01-01  0.839286  0.695833  0.530449  0.458861  0.367484
#            2015-01-01  0.848214  0.741667  0.511218  0.450158  0.361635
#            2014-01-01  0.973214  0.758333  0.543269  0.428006  0.329009
# LR         2015-01-01  0.557143  0.513333  0.394872  0.372152  0.281132
#            2013-01-01  0.514286  0.500000  0.371795  0.313924  0.232911
#            2014-01-01  0.528571  0.480000  0.358974  0.311392  0.248428
# DT         2013-01-01  0.244709  0.152469  0.193257  0.294890  0.244374
#            2015-01-01  0.197090  0.132099  0.215337  0.289264  0.237538
#            2014-01-01  0.238095  0.187654  0.213438  0.289147  0.235034
#
#                         p_at_30   p_at_50
# model_type split_date
# RF         2013-01-01  0.305935  0.196159
#            2015-01-01  0.304359  0.197236
#            2014-01-01  0.289916  0.199749
# LR         2015-01-01  0.239496  0.188442
#            2013-01-01  0.216807  0.183627
#            2014-01-01  0.228151  0.183668
# DT         2013-01-01  0.203431  0.197500
#            2015-01-01  0.190787  0.193537
#            2014-01-01  0.192421  0.194072

# %% [markdown]
# # Checking precision over time for each classifier

# %%
m = 0
n = 3
while n < 10:
    df = summary[p_list].reset_index().iloc[m:n]
    df.set_index('split_date').plot(figsize = (10,5), 
                                grid = True, 
                                title = "Precision over time for classifier {}".format(df['model_type'].iloc[0]))
    plt.show()
    m += 3
    n += 3

# %%
summary[p_list].sort_values(by='p_at_10', ascending=False)
# Out:
#                          p_at_1    p_at_2    p_at_5   p_at_10   p_at_20  \
# model_type split_date
# RF         2013-01-01  0.839286  0.695833  0.530449  0.458861  0.367484
#            2015-01-01  0.848214  0.741667  0.511218  0.450158  0.361635
#            2014-01-01  0.973214  0.758333  0.543269  0.428006  0.329009
# LR         2015-01-01  0.557143  0.513333  0.394872  0.372152  0.281132
#            2013-01-01  0.514286  0.500000  0.371795  0.313924  0.232911
#            2014-01-01  0.528571  0.480000  0.358974  0.311392  0.248428
# DT         2013-01-01  0.244709  0.152469  0.193257  0.294890  0.244374
#            2015-01-01  0.197090  0.132099  0.215337  0.289264  0.237538
#            2014-01-01  0.238095  0.187654  0.213438  0.289147  0.235034
#
#                         p_at_30   p_at_50
# model_type split_date
# RF         2013-01-01  0.305935  0.196159
#            2015-01-01  0.304359  0.197236
#            2014-01-01  0.289916  0.199749
# LR         2015-01-01  0.239496  0.188442
#            2013-01-01  0.216807  0.183627
#            2014-01-01  0.228151  0.183668
# DT         2013-01-01  0.203431  0.197500
#            2015-01-01  0.190787  0.193537
#            2014-01-01  0.192421  0.194072

# %% [markdown]
# # Checking recall over time for each classifier

# %%
m = 0
n = 3
while n < 10:
    df = summary[recall_list].reset_index().iloc[m:n]
    df.set_index('split_date').plot(figsize = (10,5), 
                                grid = True, 
                                title = "Recall over time for classifier {}".format(df['model_type'].iloc[0]))
    plt.show()
    m += 3
    n += 3

# %%
summary[recall_list].sort_values(by='recall_at_10', ascending=False)
# Out:
#                        recall_at_1  recall_at_2  recall_at_5  recall_at_10  \
# model_type split_date
# RF         2013-01-01     0.073437     0.130469     0.258594      0.453125
#            2015-01-01     0.074219     0.139062     0.249219      0.444531
#            2014-01-01     0.085156     0.142187     0.264844      0.422656
# LR         2015-01-01     0.048750     0.096250     0.192500      0.367500
#            2013-01-01     0.045000     0.093750     0.181250      0.310000
#            2014-01-01     0.046250     0.090000     0.175000      0.307500
# DT         2013-01-01     0.021412     0.028588     0.094213      0.291204
#            2015-01-01     0.017245     0.024769     0.104977      0.285648
#            2014-01-01     0.020833     0.035185     0.104051      0.285532
#
#                        recall_at_20  recall_at_30  recall_at_50
# model_type split_date
# RF         2013-01-01      0.725781      0.910156      0.973437
#            2015-01-01      0.718750      0.905469      0.981250
#            2014-01-01      0.653906      0.862500      0.993750
# LR         2015-01-01      0.558750      0.712500      0.937500
#            2013-01-01      0.460000      0.645000      0.911250
#            2014-01-01      0.493750      0.678750      0.913750
# DT         2013-01-01      0.482639      0.605208      0.980093
#            2015-01-01      0.472106      0.567593      0.962847
#            2014-01-01      0.467130      0.572454      0.965509

# %%
metric = 'f1_at_10'
highest_f1 = models[models[metric] == models[metric].max()]
highest_f1
# Out:
#      Unnamed: 0 model_type                                                clf  \
# 13           13         DT  DecisionTreeClassifier(class_weight=None, crit...
# 112         112         LR  LogisticRegression(C=10, class_weight=None, du...
# 380         380         LR  LogisticRegression(C=10, class_weight=None, du...
#
#                                             parameters  split_date  \
# 13   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 112                        {'C': 0.1, 'penalty': 'l1'}  2013-01-01
# 380                        {'C': 0.1, 'penalty': 'l1'}  2015-01-01
#
#     min_year_in_train max_year_in_train min_year_in_test max_year_in_test  \
# 13         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 112        2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 380        2010-01-01        2014-01-01       2015-01-01       2015-01-01
#
#      baseline  ...   p_at_20  recall_at_20  f1_at_20   p_at_30  recall_at_30  \
# 13   0.100756  ...  0.322785        0.6375  0.428571  0.302521        0.9000
# 112  0.100756  ...  0.379747        0.7500  0.504202  0.298319        0.8875
# 380  0.100503  ...  0.389937        0.7750  0.518828  0.302521        0.9000
#
#      f1_at_30   p_at_50  recall_at_50  f1_at_50   auc-roc
# 13   0.452830  0.201511        1.0000  0.335430  0.893522
# 112  0.446541  0.196474        0.9750  0.327044  0.906434
# 380  0.452830  0.198492        0.9875  0.330544  0.912439
#
# [3 rows x 32 columns]

# %%
highest_f1['parameters'].values
# Out:
# array(["{'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5}",
#        "{'C': 0.1, 'penalty': 'l1'}", "{'C': 0.1, 'penalty': 'l1'}"],
#       dtype=object)

# %%
metric_auc = 'auc-roc'
highest_auc = models[models[metric_auc] == models[metric_auc].max()]
highest_auc
# Out:
#      Unnamed: 0 model_type                                                clf  \
# 380         380         LR  LogisticRegression(C=10, class_weight=None, du...
#
#                       parameters  split_date min_year_in_train  \
# 380  {'C': 0.1, 'penalty': 'l1'}  2015-01-01        2010-01-01
#
#     max_year_in_train min_year_in_test max_year_in_test  baseline  ...  \
# 380        2014-01-01       2015-01-01       2015-01-01  0.100503  ...
#
#       p_at_20  recall_at_20  f1_at_20   p_at_30  recall_at_30  f1_at_30  \
# 380  0.389937         0.775  0.518828  0.302521           0.9   0.45283
#
#       p_at_50  recall_at_50  f1_at_50   auc-roc
# 380  0.198492        0.9875  0.330544  0.912439
#
# [1 rows x 32 columns]

# %%
highest_auc['parameters'].values
# Out:
# array(["{'C': 0.1, 'penalty': 'l1'}"], dtype=object)

# %%
summary = pd.pivot_table(models,
                         index='model_type',
                         aggfunc='max',
                         fill_value=0)
f1_list = ['f1_at_1', 'f1_at_2', 'f1_at_5',
           'f1_at_10', 'f1_at_20', 'f1_at_30', 'f1_at_50']
p_list = ['p_at_1', 'p_at_2', 'p_at_5', 
          'p_at_10', 'p_at_20', 'p_at_30', 'p_at_50']
recall_list = ['recall_at_1', 'recall_at_2', 'recall_at_5', 
               'recall_at_10', 'recall_at_20', 'recall_at_30', 'recall_at_50']

# %%
fig, ax = plt.subplots()
grouped = models.groupby(['model_type', 'parameters']).mean()\
.sort_values('p_at_10', ascending=False).reset_index()

grouped['model'] = grouped.agg('{0[model_type]} {0[parameters]}'.format, axis=1)
#grouped[['model', 'model_type', 'parameters', 'p_at_10']].head(20).plot.bar(x = 'model', ax=ax)
grouped[['model', 'model_type', 'parameters', 'p_at_10', 'recall_at_10']].head(20)
# ax.set_ylim([0.3,0.6])
# plt.title('Precision at 10 of top 20 models', fontsize=15)
# plt.show()
#plt.savefig('../figures/precision.png')
# Out:
#                                                 model model_type  \
# 0                      LR {'C': 0.1, 'penalty': 'l1'}         LR
# 1   DT {'criterion': 'entropy', 'max_depth': 1, 'm...         DT
# 2   DT {'criterion': 'entropy', 'max_depth': 1, 'm...         DT
# 3   DT {'criterion': 'entropy', 'max_depth': 1, 'm...         DT
# 4   DT {'criterion': 'gini', 'max_depth': 1, 'max_...         DT
# 5   DT {'criterion': 'gini', 'max_depth': 1, 'max_...         DT
# 6   DT {'criterion': 'gini', 'max_depth': 1, 'max_...         DT
# 7                      LR {'C': 0.1, 'penalty': 'l2'}         LR
# 8   RF {'max_depth': 50, 'max_features': 'sqrt', '...         RF
# 9   RF {'max_depth': 50, 'max_features': 'sqrt', '...         RF
# 10  RF {'max_depth': 50, 'max_features': 'sqrt', '...         RF
# 11  RF {'max_depth': 5, 'max_features': 'sqrt', 'm...         RF
# 12  RF {'max_depth': 50, 'max_features': 'log2', '...         RF
# 13  DT {'criterion': 'entropy', 'max_depth': 5, 'm...         DT
# 14  RF {'max_depth': 5, 'max_features': 'sqrt', 'm...         RF
# 15  DT {'criterion': 'entropy', 'max_depth': 5, 'm...         DT
# 16  RF {'max_depth': 5, 'max_features': 'sqrt', 'm...         RF
# 17                       LR {'C': 1, 'penalty': 'l1'}         LR
# 18  RF {'max_depth': 50, 'max_features': 'sqrt', '...         RF
# 19  DT {'criterion': 'entropy', 'max_depth': 5, 'm...         DT
#
#                                            parameters   p_at_10  recall_at_10
# 0                         {'C': 0.1, 'penalty': 'l1'}  0.531646      0.525000
# 1   {'criterion': 'entropy', 'max_depth': 1, 'max_...  0.518987      0.512500
# 2   {'criterion': 'entropy', 'max_depth': 1, 'max_...  0.518987      0.512500
# 3   {'criterion': 'entropy', 'max_depth': 1, 'max_...  0.518987      0.512500
# 4   {'criterion': 'gini', 'max_depth': 1, 'max_fea...  0.518987      0.512500
# 5   {'criterion': 'gini', 'max_depth': 1, 'max_fea...  0.518987      0.512500
# 6   {'criterion': 'gini', 'max_depth': 1, 'max_fea...  0.518987      0.512500
# 7                         {'C': 0.1, 'penalty': 'l2'}  0.489451      0.483333
# 8   {'max_depth': 50, 'max_features': 'sqrt', 'min...  0.485232      0.479167
# 9   {'max_depth': 50, 'max_features': 'sqrt', 'min...  0.481013      0.475000
# 10  {'max_depth': 50, 'max_features': 'sqrt', 'min...  0.472574      0.466667
# 11  {'max_depth': 5, 'max_features': 'sqrt', 'min_...  0.472574      0.466667
# 12  {'max_depth': 50, 'max_features': 'log2', 'min...  0.472574      0.466667
# 13  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.468354      0.462500
# 14  {'max_depth': 5, 'max_features': 'sqrt', 'min_...  0.464135      0.458333
# 15  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.459916      0.454167
# 16  {'max_depth': 5, 'max_features': 'sqrt', 'min_...  0.459916      0.454167
# 17                          {'C': 1, 'penalty': 'l1'}  0.459916      0.454167
# 18  {'max_depth': 50, 'max_features': 'sqrt', 'min...  0.455696      0.450000
# 19  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.451477      0.445833

# %%
models
# Out:
#      Unnamed: 0 model_type                                                clf  \
# 0             0         DT  DecisionTreeClassifier(class_weight=None, crit...
# 1             1         DT  DecisionTreeClassifier(class_weight=None, crit...
# 2             2         DT  DecisionTreeClassifier(class_weight=None, crit...
# 3             3         DT  DecisionTreeClassifier(class_weight=None, crit...
# 4             4         DT  DecisionTreeClassifier(class_weight=None, crit...
# 5             5         DT  DecisionTreeClassifier(class_weight=None, crit...
# 6             6         DT  DecisionTreeClassifier(class_weight=None, crit...
# 7             7         DT  DecisionTreeClassifier(class_weight=None, crit...
# 8             8         DT  DecisionTreeClassifier(class_weight=None, crit...
# 9             9         DT  DecisionTreeClassifier(class_weight=None, crit...
# 10           10         DT  DecisionTreeClassifier(class_weight=None, crit...
# 11           11         DT  DecisionTreeClassifier(class_weight=None, crit...
# 12           12         DT  DecisionTreeClassifier(class_weight=None, crit...
# 13           13         DT  DecisionTreeClassifier(class_weight=None, crit...
# 14           14         DT  DecisionTreeClassifier(class_weight=None, crit...
# 15           15         DT  DecisionTreeClassifier(class_weight=None, crit...
# 16           16         DT  DecisionTreeClassifier(class_weight=None, crit...
# 17           17         DT  DecisionTreeClassifier(class_weight=None, crit...
# 18           18         DT  DecisionTreeClassifier(class_weight=None, crit...
# 19           19         DT  DecisionTreeClassifier(class_weight=None, crit...
# 20           20         DT  DecisionTreeClassifier(class_weight=None, crit...
# 21           21         DT  DecisionTreeClassifier(class_weight=None, crit...
# 22           22         DT  DecisionTreeClassifier(class_weight=None, crit...
# 23           23         DT  DecisionTreeClassifier(class_weight=None, crit...
# 24           24         DT  DecisionTreeClassifier(class_weight=None, crit...
# 25           25         DT  DecisionTreeClassifier(class_weight=None, crit...
# 26           26         DT  DecisionTreeClassifier(class_weight=None, crit...
# 27           27         DT  DecisionTreeClassifier(class_weight=None, crit...
# 28           28         DT  DecisionTreeClassifier(class_weight=None, crit...
# 29           29         DT  DecisionTreeClassifier(class_weight=None, crit...
# ..          ...        ...                                                ...
# 372         372         DT  DecisionTreeClassifier(class_weight=None, crit...
# 373         373         DT  DecisionTreeClassifier(class_weight=None, crit...
# 374         374         DT  DecisionTreeClassifier(class_weight=None, crit...
# 375         375         DT  DecisionTreeClassifier(class_weight=None, crit...
# 376         376         LR  LogisticRegression(C=10, class_weight=None, du...
# 377         377         LR  LogisticRegression(C=10, class_weight=None, du...
# 378         378         LR  LogisticRegression(C=10, class_weight=None, du...
# 379         379         LR  LogisticRegression(C=10, class_weight=None, du...
# 380         380         LR  LogisticRegression(C=10, class_weight=None, du...
# 381         381         LR  LogisticRegression(C=10, class_weight=None, du...
# 382         382         LR  LogisticRegression(C=10, class_weight=None, du...
# 383         383         LR  LogisticRegression(C=10, class_weight=None, du...
# 384         384         LR  LogisticRegression(C=10, class_weight=None, du...
# 385         385         LR  LogisticRegression(C=10, class_weight=None, du...
# 386         386         RF  RandomForestClassifier(bootstrap=True, class_w...
# 387         387         RF  RandomForestClassifier(bootstrap=True, class_w...
# 388         388         RF  RandomForestClassifier(bootstrap=True, class_w...
# 389         389         RF  RandomForestClassifier(bootstrap=True, class_w...
# 390         390         RF  RandomForestClassifier(bootstrap=True, class_w...
# 391         391         RF  RandomForestClassifier(bootstrap=True, class_w...
# 392         392         RF  RandomForestClassifier(bootstrap=True, class_w...
# 393         393         RF  RandomForestClassifier(bootstrap=True, class_w...
# 394         394         RF  RandomForestClassifier(bootstrap=True, class_w...
# 395         395         RF  RandomForestClassifier(bootstrap=True, class_w...
# 396         396         RF  RandomForestClassifier(bootstrap=True, class_w...
# 397         397         RF  RandomForestClassifier(bootstrap=True, class_w...
# 398         398         RF  RandomForestClassifier(bootstrap=True, class_w...
# 399         399         RF  RandomForestClassifier(bootstrap=True, class_w...
# 400         400         RF  RandomForestClassifier(bootstrap=True, class_w...
# 401         401         RF  RandomForestClassifier(bootstrap=True, class_w...
#
#                                             parameters  split_date  \
# 0    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 1    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 2    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 3    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 4    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 5    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 6    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 7    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 8    {'criterion': 'gini', 'max_depth': 1, 'max_fea...  2013-01-01
# 9    {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 10   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 11   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 12   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 13   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 14   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 15   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 16   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 17   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  2013-01-01
# 18   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 19   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 20   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 21   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 22   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 23   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 24   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 25   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 26   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  2013-01-01
# 27   {'criterion': 'gini', 'max_depth': 20, 'max_fe...  2013-01-01
# 28   {'criterion': 'gini', 'max_depth': 20, 'max_fe...  2013-01-01
# 29   {'criterion': 'gini', 'max_depth': 20, 'max_fe...  2013-01-01
# ..                                                 ...         ...
# 372  {'criterion': 'entropy', 'max_depth': 100, 'ma...  2015-01-01
# 373  {'criterion': 'entropy', 'max_depth': 100, 'ma...  2015-01-01
# 374  {'criterion': 'entropy', 'max_depth': 100, 'ma...  2015-01-01
# 375  {'criterion': 'entropy', 'max_depth': 100, 'ma...  2015-01-01
# 376                      {'C': 1e-05, 'penalty': 'l1'}  2015-01-01
# 377                      {'C': 1e-05, 'penalty': 'l2'}  2015-01-01
# 378                      {'C': 0.001, 'penalty': 'l1'}  2015-01-01
# 379                      {'C': 0.001, 'penalty': 'l2'}  2015-01-01
# 380                        {'C': 0.1, 'penalty': 'l1'}  2015-01-01
# 381                        {'C': 0.1, 'penalty': 'l2'}  2015-01-01
# 382                          {'C': 1, 'penalty': 'l1'}  2015-01-01
# 383                          {'C': 1, 'penalty': 'l2'}  2015-01-01
# 384                         {'C': 10, 'penalty': 'l1'}  2015-01-01
# 385                         {'C': 10, 'penalty': 'l2'}  2015-01-01
# 386  {'max_depth': 5, 'max_features': 'sqrt', 'min_...  2015-01-01
# 387  {'max_depth': 5, 'max_features': 'sqrt', 'min_...  2015-01-01
# 388  {'max_depth': 5, 'max_features': 'sqrt', 'min_...  2015-01-01
# 389  {'max_depth': 5, 'max_features': 'sqrt', 'min_...  2015-01-01
# 390  {'max_depth': 5, 'max_features': 'log2', 'min_...  2015-01-01
# 391  {'max_depth': 5, 'max_features': 'log2', 'min_...  2015-01-01
# 392  {'max_depth': 5, 'max_features': 'log2', 'min_...  2015-01-01
# 393  {'max_depth': 5, 'max_features': 'log2', 'min_...  2015-01-01
# 394  {'max_depth': 50, 'max_features': 'sqrt', 'min...  2015-01-01
# 395  {'max_depth': 50, 'max_features': 'sqrt', 'min...  2015-01-01
# 396  {'max_depth': 50, 'max_features': 'sqrt', 'min...  2015-01-01
# 397  {'max_depth': 50, 'max_features': 'sqrt', 'min...  2015-01-01
# 398  {'max_depth': 50, 'max_features': 'log2', 'min...  2015-01-01
# 399  {'max_depth': 50, 'max_features': 'log2', 'min...  2015-01-01
# 400  {'max_depth': 50, 'max_features': 'log2', 'min...  2015-01-01
# 401  {'max_depth': 50, 'max_features': 'log2', 'min...  2015-01-01
#
#     min_year_in_train max_year_in_train min_year_in_test max_year_in_test  \
# 0          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 1          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 2          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 3          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 4          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 5          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 6          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 7          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 8          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 9          2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 10         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 11         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 12         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 13         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 14         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 15         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 16         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 17         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 18         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 19         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 20         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 21         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 22         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 23         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 24         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 25         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 26         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 27         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 28         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# 29         2010-01-01        2012-01-01       2013-01-01       2013-01-01
# ..                ...               ...              ...              ...
# 372        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 373        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 374        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 375        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 376        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 377        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 378        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 379        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 380        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 381        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 382        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 383        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 384        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 385        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 386        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 387        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 388        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 389        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 390        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 391        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 392        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 393        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 394        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 395        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 396        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 397        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 398        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 399        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 400        2010-01-01        2014-01-01       2015-01-01       2015-01-01
# 401        2010-01-01        2014-01-01       2015-01-01       2015-01-01
#
#      baseline  ...   p_at_20  recall_at_20  f1_at_20   p_at_30  recall_at_30  \
# 0    0.100756  ...  0.278481        0.5500  0.369748  0.184874        0.5500
# 1    0.100756  ...  0.278481        0.5500  0.369748  0.184874        0.5500
# 2    0.100756  ...  0.278481        0.5500  0.369748  0.184874        0.5500
# 3    0.100756  ...  0.164557        0.3250  0.218487  0.281513        0.8375
# 4    0.100756  ...  0.082278        0.1625  0.109244  0.142857        0.4250
# 5    0.100756  ...  0.025316        0.0500  0.033613  0.294118        0.8750
# 6    0.100756  ...  0.303797        0.6000  0.403361  0.214286        0.6375
# 7    0.100756  ...  0.126582        0.2500  0.168067  0.189076        0.5625
# 8    0.100756  ...  0.056962        0.1125  0.075630  0.138655        0.4125
# 9    0.100756  ...  0.297468        0.5875  0.394958  0.289916        0.8625
# 10   0.100756  ...  0.297468        0.5875  0.394958  0.289916        0.8625
# 11   0.100756  ...  0.284810        0.5625  0.378151  0.285714        0.8500
# 12   0.100756  ...  0.215190        0.4250  0.285714  0.231092        0.6875
# 13   0.100756  ...  0.322785        0.6375  0.428571  0.302521        0.9000
# 14   0.100756  ...  0.170886        0.3375  0.226891  0.277311        0.8250
# 15   0.100756  ...  0.265823        0.5250  0.352941  0.264706        0.7875
# 16   0.100756  ...  0.234177        0.4625  0.310924  0.273109        0.8125
# 17   0.100756  ...  0.303797        0.6000  0.403361  0.201681        0.6000
# 18   0.100756  ...  0.272152        0.5375  0.361345  0.239496        0.7125
# 19   0.100756  ...  0.284810        0.5625  0.378151  0.247899        0.7375
# 20   0.100756  ...  0.272152        0.5375  0.361345  0.252101        0.7500
# 21   0.100756  ...  0.259494        0.5125  0.344538  0.256303        0.7625
# 22   0.100756  ...  0.329114        0.6500  0.436975  0.268908        0.8000
# 23   0.100756  ...  0.278481        0.5500  0.369748  0.256303        0.7625
# 24   0.100756  ...  0.246835        0.4875  0.327731  0.189076        0.5625
# 25   0.100756  ...  0.272152        0.5375  0.361345  0.231092        0.6875
